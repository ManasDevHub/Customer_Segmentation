# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasDevHub/Customer_Segmentation/blob/main/Customer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🛍️ Mall Customer Segmentation using KMeans Clustering
# Analyze Customer Behavior Based on Annual Income and Spending Score
#
# - In this project, we perform customer segmentation for a mall using KMeans clustering.
# We analyze customers based on their Annual Income and Spending Score to identify different customer groups.
# This helps the mall design targeted marketing strategies to boost sales and customer satisfaction.

# %%
# !pip install seaborn
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-18cb095a-3244-4558-9649-c0aa4e0d6593" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18cb095a-3244-4558-9649-c0aa4e0d6593">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Mall_Customers.csv')
df.head()
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# Basic data analysis
df.info
df.describe()
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Data visualization
# Distribution of Age
sns.histplot(df['Age'], kde = True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# Income vs Spending Score
plt.figure(figsize=(8,5))
sns.scatterplot(x = 'Annual Income (k$)', y = 'Spending Score (1-100)', data = df)
plt.title('Income vs Spending Score')
# Out:
# Text(0.5, 1.0, 'Income vs Spending Score')

# %%
# Gender Count
sns.countplot(x = 'Gender', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Select Features for Clustering
x = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
# Find Optimal Number of Clusters (Elbow Method)
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Apply K-Means
# Suppose elbow shows 5 clusters:

kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(x)

# %%
# Add the cluster labels to the original dataset:
df['Cluster'] = y_kmeans
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0           1    Male   19                  15                      39        4
# 1           2    Male   21                  15                      81        2
# 2           3  Female   20                  16                       6        4
# 3           4  Female   23                  16                      77        2
# 4           5  Female   31                  17                      40        4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['CustomerID'].plot(kind='hist', bins=20, title='CustomerID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
# Visualize the Clusters
# Visualize the Clusters
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', palette='Set1')
plt.title('Customer Segments')
plt.show()

# %% [markdown]
# ✨ Step 9: Analysis and Conclusion
# 📊 Cluster Interpretations:
#
# Cluster	Meaning	Description
# Cluster 0	High Income, Low Spending	Customers who earn well but are cautious in spending.
# Cluster 1	Low Income, High Spending	Customers with limited income but tend to spend a lot.
# Cluster 2	Average Income, Average Spending	Customers with moderate income and balanced spending habits.
# Cluster 3	High Income, High Spending	Premium customers who both earn and spend heavily.
# Cluster 4	Low Income, Low Spending	Budget-conscious customers with limited income and spending.
# 🛒 Which customer group should the mall target more?
# ✅ Cluster 3 (High Income, High Spending) should be the main target.
# These customers have:
#
# High purchasing power
#
# Willingness to spend
#
# Potential to buy luxury or premium products
#
# Strategy:
#
# Offer personalized deals
#
# Launch loyalty programs
#
# Introduce premium product lines
#
# Provide exclusive experiences
#
# ✅ Cluster 1 (Low Income, High Spending) can be targeted secondarily.
# These customers:
#
# Spend impulsively despite low income
#
# Are good targets for seasonal sales and promotions
#
# Strategy:
#
# Heavy discounts
#
# "Buy 1 Get 1" offers
#
# Membership benefits
#
# ✅ Final Conclusion:
# By identifying different customer clusters based on income and spending behavior, malls can design targeted marketing campaigns, improve customer satisfaction, and boost overall sales effectively.
